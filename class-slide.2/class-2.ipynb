# %%
# concatenation of a string

str = 'hello'
str1 = str + 's'

print(str)
print(str1)
# Out:
# hello
# hellos

# %%
# example of pending a num(ber) list
list = [1,2]
list.append(3)

print(list)
# Out:
# [1, 2, 3]

# %%
#indexing and slicing
mystr = '123456789abcdefghijklmnop'
print(mystr[2::3])
print(mystr[2:-1:6])
print(mystr[2-6:3])
# Out:
# 369cfilo
# 39fl
